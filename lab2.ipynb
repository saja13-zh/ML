# %%
import numpy as np
import pandas as pd

# %%
covidtotals= pd.read_csv(r"C:\Users\sajaz\Downloads\covidtotals.csv")

# %%
parse_data=[['lastdate']]

# %%
print(covidtotals.dtypes)
print(covidtotals.shape)
print(covidtotals.index)
print(covidtotals.index.nunique())
# Out:
# iso_code            object
# lastdate            object
# location            object
# total_cases          int64
# total_deaths         int64
# total_cases_pm     float64
# total_deaths_pm    float64
# population         float64
# pop_density        float64
# median_age         float64
# gdp_per_capita     float64
# hosp_beds          float64
# dtype: object
# (210, 12)
# RangeIndex(start=0, stop=210, step=1)
# 210

# %%
covidtotals.head(3).T
# Out:
#                            0           1           2
# iso_code                 AFG         ALB         DZA
# lastdate          2020-06-01  2020-06-01  2020-06-01
# location         Afghanistan     Albania     Algeria
# total_cases            15205        1137        9394
# total_deaths             257          33         653
# total_cases_pm       390.589     395.093     214.225
# total_deaths_pm        6.602      11.467      14.891
# population        38928341.0   2877800.0  43851043.0
# pop_density           54.422     104.871      17.348
# median_age              18.6        38.0        29.1
# gdp_per_capita      1803.987   11803.431   13913.839
# hosp_beds                0.5        2.89         1.9

# %%
covidtotals.tail(3).T
# Out:
#                         207         208         209
# iso_code                YEM         ZMB         ZWE
# lastdate         2020-06-01  2020-06-01  2020-06-01
# location              Yemen      Zambia    Zimbabwe
# total_cases             323        1057         178
# total_deaths             80           7           4
# total_cases_pm       10.829      57.496      11.976
# total_deaths_pm       2.682       0.381       0.269
# population       29825968.0  18383956.0  14862927.0
# pop_density          53.508      22.995      42.729
# median_age             20.3        17.7        19.6
# gdp_per_capita     1479.147    3689.251    1899.775
# hosp_beds               0.7         2.0         1.7

# %%
covidtotals.describe()
# Out:
#         total_cases   total_deaths  total_cases_pm  total_deaths_pm  \
# count  2.100000e+02     210.000000      210.000000       210.000000
# mean   2.921614e+04    1770.714286     1355.357943        55.659129
# std    1.363978e+05    8705.565857     2625.277497       144.785816
# min    0.000000e+00       0.000000        0.000000         0.000000
# 25%    1.757500e+02       4.000000       92.541500         0.884750
# 50%    1.242500e+03      25.500000      280.928500         6.154000
# 75%    1.011700e+04     241.250000     1801.394750        31.777250
# max    1.790191e+06  104383.000000    19771.348000      1237.551000
#
#          population   pop_density  median_age  gdp_per_capita   hosp_beds
# count  2.100000e+02    198.000000  186.000000      182.000000  164.000000
# mean   3.694276e+07    362.867434   30.627957    19539.154588    3.012671
# std    1.425092e+08   1581.438294    9.133152    19862.354091    2.464917
# ...

# %%
covidtotals["total_cases"].quantile(np.arange(0.0, 1.1, 0.1))
# Out:
# 0.0          0.0
# 0.1         22.9
# 0.2        105.2
# 0.3        302.0
# 0.4        762.0
# 0.5       1242.5
# 0.6       2514.6
# 0.7       6959.8
# 0.8      16847.2
# 0.9      46513.1
# 1.0    1790191.0
# Name: total_cases, dtype: float64

# %%
covidtotals["total_deaths"].quantile(np.arange(0.0, 1.1, 0.1))
# Out:
# 0.0         0.0
# 0.1         0.0
# 0.2         2.0
# 0.3         6.7
# 0.4        12.0
# 0.5        25.5
# 0.6        54.6
# 0.7       137.2
# 0.8       323.2
# 0.9      1616.9
# 1.0    104383.0
# Name: total_deaths, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(covidtotals['total_cases'], bins=30)

plt.title("total_cases")

plt.xlabel('income')

plt.ylabel("Number of individuals")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(covidtotals['total_deaths'], bins=30)

plt.title("total_deaths")

plt.xlabel('income')

plt.ylabel("Number of individuals")

plt.show()

# %% [markdown]
# A distribution is skewed if one of its tails is longer than the other and The graph shows the skewed to the right so the graph has a positive skew becouse the mean value larger then median
